# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Vlad/Desktop/OR Case Study/MS-E2177-Case-Study/npvs_of_assets_and_liabilities.csv')

# %%
df.iloc[:,1:3].plot(kind='bar', figsize=(12, 8), title='PVs of cash flows of liabilities and assets')
# Out:
# <AxesSubplot:title={'center':'PVs of cash flows of liabilities and assets'}>

# %%
df.iloc[:,1:3].mean()
# Out:
# PVs_liabilities_0    8.371551e+07
# PVs_assets_0         1.509385e+08
# dtype: float64

# %%
df.iloc[:,3:5].plot(kind='bar', figsize=(12, 8), secondary_y=[df.columns[4]])
# Out:
# <AxesSubplot:>

# %%
df.columns[5]
# Out:
# 'PVs_liabilities_1'
